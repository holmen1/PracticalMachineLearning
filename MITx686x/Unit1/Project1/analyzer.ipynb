# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("reviews_train.tsv", sep='\t')

# %%
df.head()
# Out:
#    sentiment   productId          userId  \
# 0         -1  B000EQYQBO  A2JZVE0Y19VLL0
# 1         -1  B000LKVHYC  A3NAKOMAS0I5L9
# 2         -1  B003QRQRY2   ARBO3XW14MNGA
# 3         -1  B008EG58V8  A1IQXGT4MJUYJ8
# 4          1  B004WZZY8M  A2TBL6WAZGXB9P
#
#                                              summary  \
# 0                                         blue chips
# 1                             Bad even for 'healthy'
# 2                          Alot of money for one can
# 3  The Box says "OATMEAL SQUARES" which I believe...
# 4                                         Delicious!
#
#                                                 text  helpfulY  helpfulN
# 0  The chips are okay Not near as flavorful as th...         0         0
# 1  I had high hopes for this, but it was bad.  Re...         0         0
# 2  I guess it's only one can since there is nothi...         1         1
# 3  "Oatmeal Squares" is in about the largest prin...         0         0
# ...

# %%
df.describe()
# Out:
#          sentiment     helpfulY    helpfulN
# count  4000.000000  4000.000000  4000.00000
# mean     -0.015000     1.888500     0.85525
# std       1.000013     6.505817     2.67359
# min      -1.000000     0.000000     0.00000
# 25%      -1.000000     0.000000     0.00000
# 50%      -1.000000     0.000000     0.00000
# 75%       1.000000     2.000000     1.00000
# max       1.000000   180.000000    62.00000

# %%
df[['text','sentiment']]
# Out:
#                                                    text  sentiment
# 0     The chips are okay Not near as flavorful as th...         -1
# 1     I had high hopes for this, but it was bad.  Re...         -1
# 2     I guess it's only one can since there is nothi...         -1
# 3     "Oatmeal Squares" is in about the largest prin...         -1
# 4     I really enjoyed this flavor, this has a very ...          1
# 5     Awful!  not coffee this is instant coffee and ...         -1
# 6     I was sorely disappointed in these cookies.. T...         -1
# 7     My 10 year-old black pug has problems with her...          1
# 8     I've been looking for dried bell peppers ever ...          1
# 9     Dont go into this thinking after you mix up yo...          1
# 10    If you are looking for a lightly flavored gree...          1
# 11    I find this to be a good product...good spicy ...         -1
# 12    My cat had a very bad reaction to these treats...         -1
# ...
